# %%
import pandas as pd

df = pd.read_csv("data.csv", encoding="utf-8", on_bad_lines="skip")
data = df.to_numpy()   # back to NumPy if you need it
print(data)
# Out:
# [[4 'Alexander Strehmel' 'Stuttgart' ... 0.0 0.0 0.0]
#  [4 'Alexander Strehmel' 'Stuttgart' ... 0.0 0.0 0.0]
#  [4 'Alexander Strehmel' 'Unterhaching' ... 0.0 0.0 0.0]
#  ...
#  [24717 'Victor Nelsson' 'Roma' ... 0.0 0.0 0.0]
#  [24718 'William Feola' 'Como' ... 0.0 0.0 0.0]
#  [24719 'Zion Suzuki' 'Parma' ... 0.0 0.0 0.0]]

# %%
print(data.shape)       # (rows, columns)
print(data.dtype)       # data type
# Out:
# (92170, 120)
# object

# %%
col3 = data[2:, :]
print(col3)
# Out:
# [[4 'Alexander Strehmel' 'Unterhaching' ... 0.0 0.0 0.0]
#  [4 'Alexander Strehmel' 'Unterhaching' ... 0.0 0.0 0.0]
#  [6 'Alois Reinhardt' 'Bayern Munich' ... 0.0 0.0 0.0]
#  ...
#  [24717 'Victor Nelsson' 'Roma' ... 0.0 0.0 0.0]
#  [24718 'William Feola' 'Como' ... 0.0 0.0 0.0]
#  [24719 'Zion Suzuki' 'Parma' ... 0.0 0.0 0.0]]

# %%
col=data[1:3,1:5]
print(col)
# Out:
# [['Alexander Strehmel' 'Stuttgart' 'Bundesliga' 'GER']
#  ['Alexander Strehmel' 'Unterhaching' 'Bundesliga' 'GER']]

# %%
print(data.shape)
# Out:
# (92170, 120)

# %%
data.reshape(data.size)
# Out:
# array([4, 'Alexander Strehmel', 'Stuttgart', ..., 0.0, 0.0, 0.0],
#       shape=(11060400,), dtype=object)

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 11060400

# %%
data.shape
# Out:
# (92170, 120)
